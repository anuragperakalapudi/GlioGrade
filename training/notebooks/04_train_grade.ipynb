# %% [markdown]
# # 04 — Grade Classifier (3-class)
#
# Trains the grade model: Grade 2 vs Grade 3 vs Grade 4.
# MedicalNet ResNet-10 backbone, class-weighted cross-entropy, stratified split.
# Saves best checkpoint to Google Drive.
#
# **Prerequisites:** Binary classifier (03) must have passed validation checkpoint.
#
# **Run after:** `03_train_binary.ipynb`
# **Run before:** `05_train_type.ipynb`

# %%
# ── Config ───────────────────────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

MANIFEST_CSV = '/content/drive/MyDrive/GlioGrade/preprocessed/manifest.csv'
MODEL_OUT    = '/content/drive/MyDrive/GlioGrade/models'
NUM_CLASSES  = 3     # Grade 2, 3, 4
BATCH_SIZE   = 4
EPOCHS_HEAD  = 10
EPOCHS_FULL  = 50
LR_HEAD      = 1e-3
LR_FULL      = 1e-4
SEED         = 42

import sys
# !git clone https://github.com/YOUR_USERNAME/GlioGrade.git /content/GlioGrade --quiet
sys.path.insert(0, '/content/GlioGrade/training/src')
print('Config ready.')
