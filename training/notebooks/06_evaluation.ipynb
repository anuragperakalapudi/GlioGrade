# %% [markdown]
# # 06 — Evaluation
#
# Full evaluation of trained type and grade models on the held-out test set.
# Reports: confusion matrix, balanced accuracy, macro F1, Cohen's Kappa,
# per-class precision/recall/F1, and AUC-ROC (one-vs-rest).
#
# Never report plain accuracy as the primary metric — 80% class imbalance makes it meaningless.
#
# **Run after:** `05_train_type.ipynb`

# %%
# ── Config ───────────────────────────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

MANIFEST_CSV  = '/content/drive/MyDrive/GlioGrade/preprocessed/manifest.csv'
GRADE_MODEL   = '/content/drive/MyDrive/GlioGrade/models/grade_model.pt'
TYPE_MODEL    = '/content/drive/MyDrive/GlioGrade/models/type_model.pt'

import sys
# !git clone https://github.com/YOUR_USERNAME/GlioGrade.git /content/GlioGrade --quiet
sys.path.insert(0, '/content/GlioGrade/training/src')
print('Config ready.')
